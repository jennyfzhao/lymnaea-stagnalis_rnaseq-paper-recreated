# %%
import pandas as pd

# %%
# %%bash
#
# pip install matplotlib
#
# ls lymnaea_stagnalis_CNS_aging/data/annotation/pfam/
# Out:
# deseq2_annotated
# gene_pfam_summary.tsv
# Pfam-A.hmm
# Pfam-A.hmm.h3f
# Pfam-A.hmm.h3i
# Pfam-A.hmm.h3m
# Pfam-A.hmm.h3p
# protein_pfam_domains.tsv
# transdecoder_pfam.domtblout

# %%
df = pd.read_csv('lymnaea_stagnalis_CNS_aging/data/annotation/pfam/protein_pfam_domains.tsv', sep="\t")

# %%
# %%bash
# pwd
# Out:
# /Users/jennyfzhao/Work/task/2026-06-03_rnaseq/papers

# %%
df.head(4)
# Out:
#        gene_id  transcript_id        protein_id       pfam_name  \
# 0    MSTRG.100    MSTRG.100.1    MSTRG.100.1.p1            DEAD
# 1    MSTRG.100    MSTRG.100.1    MSTRG.100.1.p1      Helicase_C
# 2  MSTRG.10002  MSTRG.10002.1  MSTRG.10002.1.p1  Glyco_hydro_59
# 3  MSTRG.10002  MSTRG.10002.2  MSTRG.10002.2.p2  Glyco_hydro_59
#
#   pfam_accession  target_length  protein_length    full_evalue  full_score  \
# 0     PF00270.36            167             547   1.700000e-32       113.0
# 1     PF00271.38            110             547   9.200000e-30       103.7
# 2     PF02057.22            292             691  5.400000e-122       407.3
# 3     PF02057.22            292             333   3.100000e-95       319.5
#
#    domain_number  ...  domain_ievalue  domain_score  hmm_from  hmm_to  \
# 0              1  ...    3.600000e-32         112.0         1     165
# 1              1  ...    2.400000e-29         102.4         2     110
# ...

# %%
df.shape
# Out:
# (52912, 22)

# %%
import matplotlib.pyplot as plt

# %%
df.describe
# Out:
# <bound method NDFrame.describe of            gene_id  transcript_id        protein_id         pfam_name  \
# 0        MSTRG.100    MSTRG.100.1    MSTRG.100.1.p1              DEAD
# 1        MSTRG.100    MSTRG.100.1    MSTRG.100.1.p1        Helicase_C
# 2      MSTRG.10002  MSTRG.10002.1  MSTRG.10002.1.p1    Glyco_hydro_59
# 3      MSTRG.10002  MSTRG.10002.2  MSTRG.10002.2.p2    Glyco_hydro_59
# 4      MSTRG.10002  MSTRG.10002.2  MSTRG.10002.2.p1  Glyco_hydro_59_C
# ...            ...            ...               ...               ...
# 52907   MSTRG.9994   MSTRG.9994.1   MSTRG.9994.1.p1             LRR_4
# 52908   MSTRG.9994   MSTRG.9994.1   MSTRG.9994.1.p1             LRR_4
# 52909   MSTRG.9994   MSTRG.9994.1   MSTRG.9994.1.p1             LRR_4
# 52910   MSTRG.9998   MSTRG.9998.2   MSTRG.9998.2.p1               fn3
# 52911   MSTRG.9998   MSTRG.9998.1   MSTRG.9998.1.p1               fn3
#
#       pfam_accession  target_length  protein_length    full_evalue  \
# ...

# %%
# !pwd
# Out:
# /Users/jennyfzhao/Work/task/2026-06-03_rnaseq/papers
